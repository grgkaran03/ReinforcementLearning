# %% [markdown]
# ### Setting The Environment

# %%
import os
import gym
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name)

# %% [markdown]
# Test the environment by random sampling.

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print(f'Episode:{episode} Score:{score}')
env.close()
# Out:
# Episode:1 Score:22.0
# Episode:2 Score:14.0
# Episode:3 Score:27.0
# Episode:4 Score:17.0
# Episode:5 Score:42.0

# %%
log_path = os.path.join('Training', 'Logs') #deifne directories

# %%
log_path
# Out:
# 'Training\\Logs'

# %% [markdown]
# ### Set DQN model (Default)
# #### 2 layers with 64 units
# Parameters are updated by stochastic gradient descent (or a variant)
# by minimizing the square loss.

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda:env])
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log= log_path) #MLP--2 layers of 64...no fancy stuff like lstm
#verbose: log our observations
# Out:
# Using cpu device

# %%
DQN??
# Out:
# Init signature:
# DQN(
#     policy: Union[str, Type[stable_baselines3.dqn.policies.DQNPolicy]],
#     env: Union[gym.core.Env, stable_baselines3.common.vec_env.base_vec_env.VecEnv, str],
#     learning_rate: Union[float, Callable[[float], float]] = 0.0001,
#     buffer_size: int = 1000000,
#     learning_starts: int = 50000,
#     batch_size: int = 32,
#     tau: float = 1.0,
#     gamma: float = 0.99,
#     train_freq: Union[int, Tuple[int, str]] = 4,
#     gradient_steps: int = 1,
#     replay_buffer_class: Optional[Type[stable_baselines3.common.buffers.ReplayBuffer]] = None,
#     replay_buffer_kwargs: Optional[Dict[str, Any]] = None,
#     optimize_memory_usage: bool = False,
#     target_update_interval: int = 10000,
#     exploration_fraction: float = 0.1,
#     exploration_initial_eps: float = 1.0,
#     exploration_final_eps: float = 0.05,
#     max_grad_norm: float = 10,
#     tensorboard_log: Optional[str] = None,
#     policy_kwargs: Optional[Dict[str, Any]] = None,
#     verbose: int = 0,
#     seed: Optional[int] = None,
#     device: Union[torch.device, str] = 'auto',
#     _init_setup_model: bool = True,
# )
# Source:
# class DQN(OffPolicyAlgorithm):
#     """
#     Deep Q-Network (DQN)
#
#     Paper: https://arxiv.org/abs/1312.5602, https://www.nature.com/articles/nature14236
#     Default hyperparameters are taken from the Nature paper,
#     except for the optimizer and learning rate that were taken from Stable Baselines defaults.
#
#     :param policy: The policy model to use (MlpPolicy, CnnPolicy, ...)
#     :param env: The environment to learn from (if registered in Gym, can be str)
#     :param learning_rate: The learning rate, it can be a function
#         of the current progress remaining (from 1 to 0)
#     :param buffer_size: size of the replay buffer
#     :param learning_starts: how many steps of the model to collect transitions for before learning starts
#     :param batch_size: Minibatch size for each gradient update
#     :param tau: the soft update coefficient ("Polyak update", between 0 and 1) default 1 for hard update
#     :param gamma: the discount factor
#     :param train_freq: Update the model every ``train_freq`` steps. Alternatively pass a tuple of frequency and unit
#         like ``(5, "step")`` or ``(2, "episode")``.
#     :param gradient_steps: How many gradient steps to do after each rollout (see ``train_freq``)
#         Set to ``-1`` means to do as many gradient steps as steps done in the environment
#         during the rollout.
#     :param replay_buffer_class: Replay buffer class to use (for instance ``HerReplayBuffer``).
#         If ``None``, it will be automatically selected.
#     :param replay_buffer_kwargs: Keyword arguments to pass to the replay buffer on creation.
#     :param optimize_memory_usage: Enable a memory efficient variant of the replay buffer
#         at a cost of more complexity.
#         See https://github.com/DLR-RM/stable-baselines3/issues/37#issuecomment-637501195
#     :param target_update_interval: update the target network every ``target_update_interval``
#         environment steps.
#     :param exploration_fraction: fraction of entire training period over which the exploration rate is reduced
#     :param exploration_initial_eps: initial value of random action probability
#     :param exploration_final_eps: final value of random action probability
#     :param max_grad_norm: The maximum value for the gradient clipping
#     :param tensorboard_log: the log location for tensorboard (if None, no logging)
#     :param policy_kwargs: additional arguments to be passed to the policy on creation
#     :param verbose: Verbosity level: 0 for no output, 1 for info messages (such as device or wrappers used), 2 for
#         debug messages
#     :param seed: Seed for the pseudo random generators
#     :param device: Device (cpu, cuda, ...) on which the code should be run.
#         Setting it to auto, the code will be run on the GPU if possible.
#     :param _init_setup_model: Whether or not to build the network at the creation of the instance
#     """
#
#     policy_aliases: Dict[str, Type[BasePolicy]] = {
#         "MlpPolicy": MlpPolicy,
#         "CnnPolicy": CnnPolicy,
#         "MultiInputPolicy": MultiInputPolicy,
#     }
#
#     def __init__(
#         self,
#         policy: Union[str, Type[DQNPolicy]],
#         env: Union[GymEnv, str],
#         learning_rate: Union[float, Schedule] = 1e-4,
#         buffer_size: int = 1_000_000,  # 1e6
#         learning_starts: int = 50000,
#         batch_size: int = 32,
#         tau: float = 1.0,
#         gamma: float = 0.99,
#         train_freq: Union[int, Tuple[int, str]] = 4,
#         gradient_steps: int = 1,
#         replay_buffer_class: Optional[Type[ReplayBuffer]] = None,
#         replay_buffer_kwargs: Optional[Dict[str, Any]] = None,
#         optimize_memory_usage: bool = False,
#         target_update_interval: int = 10000,
#         exploration_fraction: float = 0.1,
#         exploration_initial_eps: float = 1.0,
#         exploration_final_eps: float = 0.05,
#         max_grad_norm: float = 10,
#         tensorboard_log: Optional[str] = None,
#         policy_kwargs: Optional[Dict[str, Any]] = None,
#         verbose: int = 0,
#         seed: Optional[int] = None,
#         device: Union[th.device, str] = "auto",
#         _init_setup_model: bool = True,
#     ):
#
#         super().__init__(
#             policy,
#             env,
#             learning_rate,
#             buffer_size,
#             learning_starts,
#             batch_size,
#             tau,
#             gamma,
#             train_freq,
#             gradient_steps,
#             action_noise=None,  # No action noise
#             replay_buffer_class=replay_buffer_class,
#             replay_buffer_kwargs=replay_buffer_kwargs,
#             policy_kwargs=policy_kwargs,
#             tensorboard_log=tensorboard_log,
#             verbose=verbose,
#             device=device,
#             seed=seed,
#             sde_support=False,
#             optimize_memory_usage=optimize_memory_usage,
#             supported_action_spaces=(spaces.Discrete,),
#             support_multi_env=True,
#         )
#
#         self.exploration_initial_eps = exploration_initial_eps
#         self.exploration_final_eps = exploration_final_eps
#         self.exploration_fraction = exploration_fraction
#         self.target_update_interval = target_update_interval
#         # For updating the target network with multiple envs:
#         self._n_calls = 0
#         self.max_grad_norm = max_grad_norm
#         # "epsilon" for the epsilon-greedy exploration
#         self.exploration_rate = 0.0
#         # Linear schedule will be defined in `_setup_model()`
#         self.exploration_schedule = None
#         self.q_net, self.q_net_target = None, None
#
#         if _init_setup_model:
#             self._setup_model()
#
#     def _setup_model(self) -> None:
#         super()._setup_model()
#         self._create_aliases()
#         # Copy running stats, see GH issue #996
#         self.batch_norm_stats = get_parameters_by_name(self.q_net, ["running_"])
#         self.batch_norm_stats_target = get_parameters_by_name(self.q_net_target, ["running_"])
#         self.exploration_schedule = get_linear_fn(
#             self.exploration_initial_eps,
#             self.exploration_final_eps,
#             self.exploration_fraction,
#         )
#         # Account for multiple environments
#         # each call to step() corresponds to n_envs transitions
#         if self.n_envs > 1:
#             if self.n_envs > self.target_update_interval:
#                 warnings.warn(
#                     "The number of environments used is greater than the target network "
#                     f"update interval ({self.n_envs} > {self.target_update_interval}), "
#                     "therefore the target network will be updated after each call to env.step() "
#                     f"which corresponds to {self.n_envs} steps."
#                 )
#
#             self.target_update_interval = max(self.target_update_interval // self.n_envs, 1)
#
#     def _create_aliases(self) -> None:
#         self.q_net = self.policy.q_net
#         self.q_net_target = self.policy.q_net_target
#
#     def _on_step(self) -> None:
#         """
#         Update the exploration rate and target network if needed.
#         This method is called in ``collect_rollouts()`` after each step in the environment.
#         """
#         self._n_calls += 1
#         if self._n_calls % self.target_update_interval == 0:
#             polyak_update(self.q_net.parameters(), self.q_net_target.parameters(), self.tau)
#             # Copy running stats, see GH issue #996
#             polyak_update(self.batch_norm_stats, self.batch_norm_stats_target, 1.0)
#
#         self.exploration_rate = self.exploration_schedule(self._current_progress_remaining)
#         self.logger.record("rollout/exploration_rate", self.exploration_rate)
#
#     def train(self, gradient_steps: int, batch_size: int = 100) -> None:
#         # Switch to train mode (this affects batch norm / dropout)
#         self.policy.set_training_mode(True)
#         # Update learning rate according to schedule
#         self._update_learning_rate(self.policy.optimizer)
#
#         losses = []
#         for _ in range(gradient_steps):
#             # Sample replay buffer
#             replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)
#
#             with th.no_grad():
#                 # Compute the next Q-values using the target network
#                 next_q_values = self.q_net_target(replay_data.next_observations)
#                 # Follow greedy policy: use the one with the highest value
#                 next_q_values, _ = next_q_values.max(dim=1)
#                 # Avoid potential broadcast issue
#                 next_q_values = next_q_values.reshape(-1, 1)
#                 # 1-step TD target
#                 target_q_values = replay_data.rewards + (1 - replay_data.dones) * self.gamma * next_q_values
#
#             # Get current Q-values estimates
#             current_q_values = self.q_net(replay_data.observations)
#
#             # Retrieve the q-values for the actions from the replay buffer
#             current_q_values = th.gather(current_q_values, dim=1, index=replay_data.actions.long())
#
#             # Compute Huber loss (less sensitive to outliers)
#             loss = F.smooth_l1_loss(current_q_values, target_q_values)
#             losses.append(loss.item())
#
#             # Optimize the policy
#             self.policy.optimizer.zero_grad()
#             loss.backward()
#             # Clip gradient norm
#             th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#             self.policy.optimizer.step()
#
#         # Increase update counter
#         self._n_updates += gradient_steps
#
#         self.logger.record("train/n_updates", self._n_updates, exclude="tensorboard")
#         self.logger.record("train/loss", np.mean(losses))
#
#     def predict(
#         self,
#         observation: Union[np.ndarray, Dict[str, np.ndarray]],
#         state: Optional[Tuple[np.ndarray, ...]] = None,
#         episode_start: Optional[np.ndarray] = None,
#         deterministic: bool = False,
#     ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#         """
#         Overrides the base_class predict function to include epsilon-greedy exploration.
#
#         :param observation: the input observation
#         :param state: The last states (can be None, used in recurrent policies)
#         :param episode_start: The last masks (can be None, used in recurrent policies)
#         :param deterministic: Whether or not to return deterministic actions.
#         :return: the model's action and the next state
#             (used in recurrent policies)
#         """
#         if not deterministic and np.random.rand() < self.exploration_rate:
#             if is_vectorized_observation(maybe_transpose(observation, self.observation_space), self.observation_space):
#                 if isinstance(observation, dict):
#                     n_batch = observation[list(observation.keys())[0]].shape[0]
#                 else:
#                     n_batch = observation.shape[0]
#                 action = np.array([self.action_space.sample() for _ in range(n_batch)])
#             else:
#                 action = np.array(self.action_space.sample())
#         else:
#             action, state = self.policy.predict(observation, state, episode_start, deterministic)
#         return action, state
#
#     def learn(
#         self: SelfDQN,
#         total_timesteps: int,
#         callback: MaybeCallback = None,
#         log_interval: int = 4,
#         tb_log_name: str = "DQN",
#         reset_num_timesteps: bool = True,
#         progress_bar: bool = False,
#     ) -> SelfDQN:
#
#         return super().learn(
#             total_timesteps=total_timesteps,
#             callback=callback,
#             log_interval=log_interval,
#             tb_log_name=tb_log_name,
#             reset_num_timesteps=reset_num_timesteps,
#             progress_bar=progress_bar,
#         )
#
#     def _excluded_save_params(self) -> List[str]:
#         return super()._excluded_save_params() + ["q_net", "q_net_target"]
#
#     def _get_torch_save_params(self) -> Tuple[List[str], List[str]]:
#         state_dicts = ["policy", "policy.optimizer"]
#
#         return state_dicts, []
# File:           c:\users\hp\onedrive\desktop\rl\venv\lib\site-packages\stable_baselines3\dqn\dqn.py
# Type:           ABCMeta
# Subclasses:

# %%
model.learn(total_timesteps=150000)
# Out:
# Logging to Training\Logs\DQN_10
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 7412     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 106      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 8214     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 191      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7910     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 8135     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 386      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 8137     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 486      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 8172     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 592      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 8122     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 658      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 8478     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 785      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.94     |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 8730     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 948      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.933    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 8712     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1057     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.929    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 8708     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 8644     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 8512     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1283     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 8557     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1365     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.907    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 8618     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1472     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.903    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8617     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1537     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.899    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8628     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.893    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8689     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8794     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8878     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.873    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8986     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1998     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.868    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 9045     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.861    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 9089     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2202     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.856    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 9054     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 9194     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2389     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.841    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 9321     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 9436     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2664     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 9439     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.822    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 9400     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 9407     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2888     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 9379     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2971     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.805    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 9438     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3075     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.801    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 9451     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 9511     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.788    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 9451     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3349     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 9474     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3470     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.774    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 9505     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3563     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 9467     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.767    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 9440     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.761    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 9415     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.756    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 9404     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 9341     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3937     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.746    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 9387     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4013     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.741    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 9386     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4087     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 9404     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 9381     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4225     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.726    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 9416     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4332     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.718    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 9453     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4448     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.713    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 9458     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4524     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 9480     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4626     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.702    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 9450     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.697    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 9473     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.692    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 9437     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.685    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 9484     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4966     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.68     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 9502     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5055     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.673    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 9544     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5169     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.663    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 9577     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.659    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 9567     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5391     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.649    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 9590     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 9586     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5621     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.637    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 9643     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5725     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.632    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 9593     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5803     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 9609     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.62     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 9588     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5995     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.611    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 9622     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6147     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 9604     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6227     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.602    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 9603     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.596    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 9610     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.591    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 9598     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6455     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.585    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 9591     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6552     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 9593     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6630     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 9596     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.565    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 9606     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.559    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 9587     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6961     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.555    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 9565     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.551    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 9539     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7088     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 9518     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7175     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.541    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 9526     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.535    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 9538     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7339     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.53     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 9549     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.523    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 9523     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.519    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 9525     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7601     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 9539     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7670     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 9520     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 9538     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7829     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 9542     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7928     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 9553     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8014     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 9517     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8101     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.484    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 9517     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.476    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 9521     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8271     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.472    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 9498     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8342     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.466    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 9367     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8432     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.46     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 9377     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8523     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.454    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 9402     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 9422     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.443    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 9416     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8792     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 9425     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8882     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 9402     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.428    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 9402     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9026     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.422    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 9418     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9120     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 9435     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9209     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 9445     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9306     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.406    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 9443     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9382     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.4      |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 9442     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9467     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.396    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 9425     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.391    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 9410     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9620     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.382    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 9434     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.38     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 9423     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 9433     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9891     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.369    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 9409     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9965     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.364    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 9396     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.359    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 9405     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10119    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.354    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 9406     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.349    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 9413     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10284    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 9431     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10393    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.334    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 9439     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10511    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.33     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 9443     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10580    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.326    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 9426     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.319    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 9442     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10756    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.312    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 9438     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10858    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.303    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 9455     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.299    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 9446     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11069    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.294    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 9451     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.29     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 9446     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11217    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.283    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 9442     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11316    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.28     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 9436     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11365    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.275    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 9445     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11451    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.268    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 9433     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11561    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.263    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 9407     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11633    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.256    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 9415     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.252    |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 9416     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.243    |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 9438     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11950    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.237    |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 9447     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12050    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.232    |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 9453     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12133    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 9466     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12212    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.222    |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 9451     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.217    |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 9455     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12370    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.21     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 9464     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.205    |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 9433     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.198    |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 9317     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12657    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.194    |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 9204     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12729    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.189    |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 9157     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12806    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.179    |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 9138     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12965    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.175    |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 9138     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13029    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.17     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 9110     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13102    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 9055     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13173    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.161    |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 9015     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13253    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.156    |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 8995     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13333    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.15     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 8952     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13426    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.145    |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 8925     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.136    |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 8899     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13643    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.128    |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 8850     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13763    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    n_updates        | 15679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4004     |
# |    fps              | 581      |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 113868   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00946  |
# |    n_updates        | 15966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4008     |
# |    fps              | 581      |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 115122   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.138    |
# |    n_updates        | 16280    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4012     |
# |    fps              | 578      |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 116209   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0127   |
# |    n_updates        | 16552    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4016     |
# |    fps              | 576      |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 117425   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 16856    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4020     |
# |    fps              | 578      |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 118764   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 17190    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4024     |
# |    fps              | 580      |
# |    time_elapsed     | 206      |
# |    total_timesteps  | 119947   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.21     |
# |    n_updates        | 17486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4028     |
# |    fps              | 582      |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 120967   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00319  |
# |    n_updates        | 17741    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 584      |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 122287   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.236    |
# |    n_updates        | 18071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 586      |
# |    time_elapsed     | 210      |
# |    total_timesteps  | 123450   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00786  |
# |    n_updates        | 18362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4040     |
# |    fps              | 588      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 124623   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0748   |
# |    n_updates        | 18655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4044     |
# |    fps              | 591      |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 125905   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0748   |
# |    n_updates        | 18976    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4048     |
# |    fps              | 592      |
# |    time_elapsed     | 213      |
# |    total_timesteps  | 126842   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.364    |
# |    n_updates        | 19210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4052     |
# |    fps              | 595      |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 127968   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0081   |
# |    n_updates        | 19491    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4056     |
# |    fps              | 597      |
# |    time_elapsed     | 216      |
# |    total_timesteps  | 129289   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.588    |
# |    n_updates        | 19822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4060     |
# |    fps              | 599      |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 130124   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.265    |
# |    n_updates        | 20030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4064     |
# |    fps              | 600      |
# |    time_elapsed     | 218      |
# |    total_timesteps  | 131107   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.173    |
# |    n_updates        | 20276    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4068     |
# |    fps              | 601      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 132139   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00911  |
# |    n_updates        | 20534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4072     |
# |    fps              | 603      |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 133046   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00942  |
# |    n_updates        | 20761    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4076     |
# |    fps              | 604      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 133898   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00906  |
# |    n_updates        | 20974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4080     |
# |    fps              | 604      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 134963   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.404    |
# |    n_updates        | 21240    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 601      |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 136022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.198    |
# |    n_updates        | 21505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 600      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 137015   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 21753    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 601      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 138017   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.251    |
# |    n_updates        | 22004    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4096     |
# |    fps              | 602      |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 138926   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00691  |
# |    n_updates        | 22231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 603      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 140008   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.204    |
# |    n_updates        | 22501    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4104     |
# |    fps              | 605      |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 141275   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.174    |
# |    n_updates        | 22818    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4108     |
# |    fps              | 605      |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 142267   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.246    |
# |    n_updates        | 23066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4112     |
# |    fps              | 605      |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 143120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00621  |
# |    n_updates        | 23279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4116     |
# |    fps              | 607      |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 144003   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 23500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4120     |
# |    fps              | 608      |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 144970   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00837  |
# |    n_updates        | 23742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4124     |
# |    fps              | 610      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 146004   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.148    |
# |    n_updates        | 24000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4128     |
# |    fps              | 612      |
# |    time_elapsed     | 239      |
# |    total_timesteps  | 146815   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.607    |
# |    n_updates        | 24203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4132     |
# |    fps              | 613      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 147919   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.275    |
# |    n_updates        | 24479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4136     |
# |    fps              | 614      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 148717   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 24679    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 4140     |
# |    fps              | 615      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 149620   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 24904    |
# ----------------------------------

# %% [markdown]
# Save the Model(DQN)

# %%
DQN_Path = os.path.join('Training','Saved Models', 'DQN_Model_Cartpole')

# %%
model.save(DQN_Path)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render = True)
# Out:
# c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (260.0, 61.27968668327213)

# %%
env.close()

# %% [markdown]
# Use the model to predict the next move for given state

# %%
reward_ = []
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset() #Reset the environment
    done = False
    score = 0

    while not done:
        env.render()
        action, _ = model.predict(obs) #use the prediction from trained model
        obs, reward, done, info = env.step(action)
        reward_.append(reward)
        score+=reward
    print(f'Episode:{episode} Score:{score}')
env.close()
# Out:
# Episode:1 Score:[222.]
# Episode:2 Score:[206.]
# Episode:3 Score:[256.]
# Episode:4 Score:[212.]
# Episode:5 Score:[256.]

# %%
net_arch = [dict(net_arch=dict(pi=[128, 128], vf=[128,128]))]

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
# Out:
# Using cpu device
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path, policy_kwargs={'net_arch':net_arch})
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\dqn\dqn.py:137, in DQN.__init__(self, policy, env, learning_rate, buffer_size, learning_starts, batch_size, tau, gamma, train_freq, gradient_steps, replay_buffer_class, replay_buffer_kwargs, optimize_memory_usage, target_update_interval, exploration_fraction, exploration_initial_eps, exploration_final_eps, max_grad_norm, tensorboard_log, policy_kwargs, verbose, seed, device, _init_setup_model)
#     134 self.q_net, self.q_net_target = None, None
#     136 if _init_setup_model:
# --> 137     self._setup_model()
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\dqn\dqn.py:140, in DQN._setup_model(self)
#     139 def _setup_model(self) -> None:
# --> 140     super()._setup_model()
#     141     self._create_aliases()
#     142     # Copy running stats, see GH issue #996
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py:215, in OffPolicyAlgorithm._setup_model(self)
#     204 if self.replay_buffer is None:
#     205     self.replay_buffer = self.replay_buffer_class(
#     206         self.buffer_size,
#     207         self.observation_space,
#    (...)
#     212         **self.replay_buffer_kwargs,
#     213     )
# --> 215 self.policy = self.policy_class(  # pytype:disable=not-instantiable
#     216     self.observation_space,
#     217     self.action_space,
#     218     self.lr_schedule,
#     219     **self.policy_kwargs,  # pytype:disable=not-instantiable
#     220 )
#     221 self.policy = self.policy.to(self.device)
#     223 # Convert train freq parameter to TrainFreq object
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\dqn\policies.py:148, in DQNPolicy.__init__(self, observation_space, action_space, lr_schedule, net_arch, activation_fn, features_extractor_class, features_extractor_kwargs, normalize_images, optimizer_class, optimizer_kwargs)
#     139 self.net_args = {
#     140     "observation_space": self.observation_space,
#     141     "action_space": self.action_space,
#    (...)
#     144     "normalize_images": normalize_images,
#     145 }
#     147 self.q_net, self.q_net_target = None, None
# --> 148 self._build(lr_schedule)
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\dqn\policies.py:160, in DQNPolicy._build(self, lr_schedule)
#     150 def _build(self, lr_schedule: Schedule) -> None:
#     151     """
#     152     Create the network and the optimizer.
#     153
#    (...)
#     157         lr_schedule(1) is the initial learning rate
#     158     """
# --> 160     self.q_net = self.make_q_net()
#     161     self.q_net_target = self.make_q_net()
#     162     self.q_net_target.load_state_dict(self.q_net.state_dict())
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\dqn\policies.py:171, in DQNPolicy.make_q_net(self)
#     168 def make_q_net(self) -> QNetwork:
#     169     # Make sure we always have separate networks for features extractors etc
#     170     net_args = self._update_features_extractor(self.net_args, features_extractor=None)
# --> 171     return QNetwork(**net_args).to(self.device)
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\dqn\policies.py:55, in QNetwork.__init__(self, observation_space, action_space, features_extractor, features_dim, net_arch, activation_fn, normalize_images)
#      53 self.features_dim = features_dim
#      54 action_dim = self.action_space.n  # number of actions
# ---> 55 q_net = create_mlp(self.features_dim, action_dim, self.net_arch, self.activation_fn)
#      56 self.q_net = nn.Sequential(*q_net)
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\stable_baselines3\common\torch_layers.py:133, in create_mlp(input_dim, output_dim, net_arch, activation_fn, squash_output, with_bias)
#     115 """
#     116 Create a multi layer perceptron (MLP), which is
#     117 a collection of fully-connected layers each followed by an activation function.
#    (...)
#     129 :return:
#     130 """
#     132 if len(net_arch) > 0:
# --> 133     modules = [nn.Linear(input_dim, net_arch[0], bias=with_bias), activation_fn()]
#     134 else:
#     135     modules = []
#
# File c:\Users\hp\OneDrive\Desktop\RL\venv\lib\site-packages\torch\nn\modules\linear.py:96, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#      94 self.in_features = in_features
#      95 self.out_features = out_features
# ---> 96 self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
#      97 if bias:
#      98     self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
#
# TypeError: empty() received an invalid combination of arguments - got (tuple, dtype=NoneType, device=NoneType), but expected one of:
#  * (tuple of ints size, *, tuple of names names, torch.memory_format memory_format, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
#  * (tuple of SymInts size, *, torch.memory_format memory_format, Tensor out, torch.dtype dtype, torch.layout layout, torch.device device, bool pin_memory, bool requires_grad)
